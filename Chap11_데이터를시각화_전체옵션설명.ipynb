# %%
#Chap11_데이터를시각화하기_전체옵션설치
# %matplotlib inline 
import matplotlib.pyplot as plt 
import numpy as np 

plt.plot([1,2,3,4])

# %%
#아래와 같이 x값과 y값을 받을 수 있다
plt.plot([1,2,3,4], [1,4,9,16])

# %%
#스타일을 지정할 수 있다. 
#ro는 red에 원형을 의미한다.
#b-는 blueㅇ에 실선을 의미한다. 
plt.plot([1,2,3,4], [1,4,9,16], "ro")
#plt.axis([xmin, xmax, ymin, ymax])를 의미한다. 
plt.axis([0,6,0,20])
# Out:
# (np.float64(0.0), np.float64(6.0), np.float64(0.0), np.float64(20.0))

# %%
#여러개의 그래프를 그리는 경우
#plt.plopt(x,y1,'r--',x,y2,'bs',x,y3,'g^')

#0.2간격으로 균일하게 샘플된 시간 
t = np.arange(0., 5., 0.2)

#빨간색대쉬, 파란 사각형, 녹색 삼각형 
plt.plot(t, t, 'r--', t, t**2, 'bs', t, t**3, 'g^')
# Out:
# [<matplotlib.lines.Line2D at 0x1e4fcfd89d0>,
#  <matplotlib.lines.Line2D at 0x1e4fcfd8a90>,
#  <matplotlib.lines.Line2D at 0x1e4fcfd8b20>]

# %%
#x,y값을 입력하기 
plt.plot([1,2,3,4], [2,3,5,10])

# %%
#라벨이 있는 데이터 사용하기 
data_dict = {"data_x":[1,2,3,4,5], 
    "data_y":[2,3,5,10,8]}
plt.plot("data_x", "data_y", data=data_dict)

# %%
#matplotlib축 라벨 지정하기
#xlabel(), ylabel()함수를 사용하면 된다. 
plt.plot([1,2,3,4], [1,4,9,16])
plt.xlabel('X-Label')
plt.ylabel('Y-Label')
# Out:
# Text(0, 0.5, 'Y-Label')

# %%
#여백 지정하기 
#xlabel(), ylabel()함수의 labelpad파라메터는 축 라벨의 
#여백(Padding)을 지정한다. 15pt, 20pt를 지정했다.  
plt.xlabel("X-Axis", labelpad=15)
plt.ylabel("Y-Axis", labelpad=20)
# Out:
# Text(0, 0.5, 'Y-Axis')

# %%
#폰트를 지정할 수 있다. 
plt.plot([1, 2, 3, 4], [2, 3, 5, 10])
plt.xlabel('X-Axis', labelpad=15, fontdict={'family': 'serif', 'color': 'b', 'weight': 'bold', 'size': 14})
plt.ylabel('Y-Axis', labelpad=20, fontdict={'family': 'fantasy', 'color': 'deeppink', 'weight': 'normal', 'size': 'xx-large'})
# Out:
# Text(0, 0.5, 'Y-Axis')

# %%
#좀 더 풀어서 지정할 수 있다.
font1 = {'family': 'serif',
         'color': 'b',
         'weight': 'bold',
         'size': 14
         }

font2 = {'family': 'fantasy',
         'color': 'deeppink',
         'weight': 'normal',
         'size': 'xx-large'
         }

plt.plot([1, 2, 3, 4], [2, 3, 5, 10])
plt.xlabel('X-Axis', labelpad=15, fontdict=font1)
plt.ylabel('Y-Axis', labelpad=20, fontdict=font2)
# Out:
# Text(0, 0.5, 'Y-Axis')

# %%
#위치도 지정할 수 있다.
#xlabel() 함수의 loc 파라미터는 X축 라벨 ({‘left’, ‘center’, ‘right’})
#ylabel() 함수의 loc 파라미터는 Y축 라벨 ({‘bottom’, ‘center’, ‘top’})
plt.plot([1, 2, 3, 4], [2, 3, 5, 10])
plt.xlabel('X-Axis', loc='center')
plt.ylabel('Y-Axis', loc='bottom')
# Out:
# Text(0, 0, 'Y-Axis')

# %%
import platform

from matplotlib import font_manager, rc

# y축에 -글자
plt.rcParams['axes.unicode_minus'] = False 

if platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    path = 'c:/Windows/Fonts/malgun.ttf'
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown system')
    
    #범례 (Legend)는 그래프에 데이터의 종류를 표시하기 위한 텍스트
# matplotlib.pyplot 모듈의 legend() 함수를 사용해서 
# 그래프에 범례를 표시할 수 있다.
plt.plot([1, 2, 3, 4], [2, 3, 5, 10], label='가격(원화표시)')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.legend()

# %%
# 위치를 지정할 때 
# plt.legend(loc=(0.5, 0.5))
# plt.legend(loc='lower right') 
# 와 같이 지정할 수 있다. 
plt.plot([1, 2, 3, 4], [2, 3, 5, 10], label='Price ($)')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
# plt.legend(loc=(0.0, 0.0))
# plt.legend(loc=(0.5, 0.5))
plt.legend(loc=(1.0, 1.0))

# %%
#열 갯수를 지정하기(범례를 출력할 때 열의 갯수) 
#plt.legend(ncols=1)
#plt.legend(ncols=2)
plt.plot([1, 2, 3, 4], [2, 3, 5, 10], label='Price ($)')
plt.plot([1, 2, 3, 4], [3, 5, 9, 7], label='Demand (#)')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
# plt.legend(loc='best')          # ncol = 1
plt.legend(loc='best', ncol=2)    # ncol = 2

# %%
#폰트의 크기를 지정할 수 있다. 
plt.plot([1, 2, 3, 4], [2, 3, 5, 10], label='Price ($)')
plt.plot([1, 2, 3, 4], [3, 5, 9, 7], label='Demand (#)')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
# plt.legend(loc='best')
plt.legend(loc='best', ncol=2, fontsize=14)

# %%
#축 범위 지정하기 
# matplotlib.pyplot 모듈의 xlim(), ylim(), axis() 함수를 
#사용하면 그래프의 X, Y축이 표시되는 범위를 지정할 수 있다. 
# xlim() - X축이 표시되는 범위를 지정
# ylim() - Y축이 표시되는 범위를 지정
# axis() - X, Y축이 표시되는 범위를 지정
plt.plot([1, 2, 3, 4], [2, 3, 5, 10])
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.xlim([0, 5])      # X축의 범위: [xmin, xmax]
plt.ylim([0, 20])     # Y축의 범위: [ymin, ymax]
# Out:
# (0.0, 20.0)

# %%
#axis()의 경우 아래와 같이 지정한다.  
#axis([xmin,xmax,ymin,ymax])
plt.plot([1, 2, 3, 4], [2, 3, 5, 10])
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.axis([0, 5, 0, 20])  # X, Y축의 범위: [xmin, xmax, ymin, ymax]
# Out:
# (np.float64(0.0), np.float64(5.0), np.float64(0.0), np.float64(20.0))

# %%
#옵션지정하기 
#axis() 함수는 아래와 같이 축에 관한 다양한 옵션을 제공
#'on' | 'off' | 'equal' | 'scaled' | 'tight' | 'auto' | 'normal' | 'image' | 'square'
plt.plot([1, 2, 3, 4], [2, 3, 5, 10])
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
# plt.axis('square')
plt.axis('scaled')
# Out:
# (np.float64(0.85), np.float64(4.15), np.float64(1.6), np.float64(10.4))

# %%
#축의 범위 얻기
plt.plot([1, 2, 3, 4], [2, 3, 5, 10])
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')

x_range, y_range = plt.xlim(), plt.ylim()
print(x_range, y_range)

axis_range = plt.axis('scaled')
print(axis_range)

# xlim(), ylim() 함수는 그래프 영역에 표시되는 X축, Y축의 범위를 각각 반환
# axis() 함수는 그래프 영역에 표시되는 X, Y축의 범위를 반환
# Out:
# (np.float64(0.85), np.float64(4.15)) (np.float64(1.6), np.float64(10.4))
# (np.float64(0.85), np.float64(4.15), np.float64(1.6), np.float64(10.4))

# %%
#matplotlib 선 종류 지정하기 
#plt.plot(), 포맷 문자열, 선 종류, linestyle, Solid, Dashed, Dotted, Dash-dot
plt.plot([1, 2, 3], [4, 4, 4], '-', color='C0', label='Solid')
plt.plot([1, 2, 3], [3, 3, 3], '--', color='C0', label='Dashed')
plt.plot([1, 2, 3], [2, 2, 2], ':', color='C0', label='Dotted')
plt.plot([1, 2, 3], [1, 1, 1], '-.', color='C0', label='Dash-dot')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.axis([0.8, 3.2, 0.5, 5.0])
plt.legend(loc='upper right', ncol=4)

# %%
#라인 스타일 지정하기 
plt.plot([1, 2, 3], [4, 4, 4], linestyle='solid', color='C0', label="'solid'")
plt.plot([1, 2, 3], [3, 3, 3], linestyle='dashed', color='C0', label="'dashed'")
plt.plot([1, 2, 3], [2, 2, 2], linestyle='dotted', color='C0', label="'dotted'")
plt.plot([1, 2, 3], [1, 1, 1], linestyle='dashdot', color='C0', label="'dashdot'")
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.axis([0.8, 3.2, 0.5, 5.0])
plt.legend(loc='upper right', ncol=4)
plt.tight_layout()

# %%
#선 스타일에 튜플 사용하기
plt.plot([1, 2, 3], [4, 4, 4], linestyle=(0, (1, 1)), color='C0', label='(0, (1, 1))')
plt.plot([1, 2, 3], [3, 3, 3], linestyle=(0, (1, 5)), color='C0', label='(0, (1, 5))')
plt.plot([1, 2, 3], [2, 2, 2], linestyle=(0, (5, 1)), color='C0', label='(0, (5, 1))')
plt.plot([1, 2, 3], [1, 1, 1], linestyle=(0, (3, 5, 1, 5)), color='C0', label='(0, (3, 5, 1, 5))')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.axis([0.8, 3.2, 0.5, 5.0])
plt.legend(loc='upper right', ncol=2)
plt.tight_layout()

# %%
#선과 마커 동시에 표현하기
# plt.plot([1, 2, 3, 4], [2, 3, 5, 10], 'bo-')    # 파란색 + 마커 + 실선
plt.plot([1, 2, 3, 4], [2, 3, 5, 10], 'bo--')     # 파란색 + 마커 + 점선
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
# Out:
# Text(0, 0.5, 'Y-Axis')

# %%
plt.plot([4, 5, 6], marker="H")
plt.plot([3, 4, 5], marker="d")
plt.plot([2, 3, 4], marker="x")
plt.plot([1, 2, 3], marker=11)
plt.plot([0, 1, 2], marker='$Z$')

# %%
#그리드 설정하기
x = np.arange(0, 2, 0.2)

plt.plot(x, x, 'bo')
plt.plot(x, x**2, color='#e35f62', marker='*', linewidth=2)
plt.plot(x, x**3, color='springgreen', marker='^', markersize=9)
plt.grid(True)

# %%
#눈금 표시하기
#틱 (Tick)은 그래프의 축에 간격을 구분하기 위해 표시하는 눈금
# matplotlib.pyplot 모듈의 xticks(), yticks(), tick_params() 함수를 이용해서
# 그래프에 눈금을 표시하는 방법에 대해 소개
# Keyword: plt.xticks(), plt.yticks(), plt.tick_params(), tick, 눈금 스타일
plt.plot(x, x, 'bo')
plt.plot(x, x**2, color='#e35f62', marker='*', linewidth=2)
plt.plot(x, x**3, color='forestgreen', marker='^', markersize=9)
plt.xticks([0, 1, 2])
plt.yticks(np.arange(1, 6))
# Out:
# ([<matplotlib.axis.YTick at 0x1e4febb9360>,
#   <matplotlib.axis.YTick at 0x1e4febb9150>,
#   <matplotlib.axis.YTick at 0x1e4febb86a0>,
#   <matplotlib.axis.YTick at 0x1e4febe5ff0>,
#   <matplotlib.axis.YTick at 0x1e4febe68c0>],
#  [Text(0, 1, '1'),
#   Text(0, 2, '2'),
#   Text(0, 3, '3'),
#   Text(0, 4, '4'),
#   Text(0, 5, '5')])

# %%
#타이틀 지정하기 
x = np.arange(0, 2, 0.2)

plt.plot(x, x, 'bo')
plt.plot(x, x**2, color='#e35f62', marker='*', linewidth=2)
plt.plot(x, x**3, color='forestgreen', marker='^', markersize=9)

plt.tick_params(axis='both', direction='in', length=3, pad=6, labelsize=14)
plt.title('Graph Title')
# Out:
# Text(0.5, 1.0, 'Graph Title')

# %%
#위치와 오프셋 지정하기
x = np.arange(0, 2, 0.2)

plt.plot(x, x, 'bo')
plt.plot(x, x**2, color='#e35f62', marker='*', linewidth=2)
plt.plot(x, x**3, color='forestgreen', marker='^', markersize=9)

plt.tick_params(axis='both', direction='in', length=3, pad=6, labelsize=14)
plt.title('Graph Title', loc='right', pad=20)
# Out:
# Text(1.0, 1.0, 'Graph Title')

# %%
#막대 그래프 그리기
x = np.arange(3)
years = ['2018', '2019', '2020']
values = [100, 400, 900]

plt.bar(x, values)
plt.xticks(x, years)
# Out:
# ([<matplotlib.axis.XTick at 0x1e4fec67640>,
#   <matplotlib.axis.XTick at 0x1e4fec67610>,
#   <matplotlib.axis.XTick at 0x1e4fec66e60>],
#  [Text(0, 0, '2018'), Text(1, 0, '2019'), Text(2, 0, '2020')])

# %%
#막대 그래프 색상별로 그리기
x = np.arange(3)
years = ['2018', '2019', '2020']
values = [100, 400, 900]

plt.bar(x, values, color='y')
# plt.bar(x, values, color='dodgerblue')
# plt.bar(x, values, color='C2')
# plt.bar(x, values, color='#e35f62')
plt.xticks(x, years)
# Out:
# ([<matplotlib.axis.XTick at 0x1e4fecc3820>,
#   <matplotlib.axis.XTick at 0x1e4fecc37f0>,
#   <matplotlib.axis.XTick at 0x1e4fecc3040>],
#  [Text(0, 0, '2018'), Text(1, 0, '2019'), Text(2, 0, '2020')])

# %%
x = np.arange(3)
years = ['2018', '2019', '2020']
values = [100, 400, 900]
colors = ['y', 'dodgerblue', 'C2']

plt.bar(x, values, color=colors)
plt.xticks(x, years)
# Out:
# ([<matplotlib.axis.XTick at 0x1e4fed405b0>,
#   <matplotlib.axis.XTick at 0x1e4fed40580>,
#   <matplotlib.axis.XTick at 0x1e4fed1fd30>],
#  [Text(0, 0, '2018'), Text(1, 0, '2019'), Text(2, 0, '2020')])

# %%
#수평 막대 그리기
y = np.arange(3)
years = ['2018', '2019', '2020']
values = [100, 400, 900]

plt.barh(y, values)
plt.yticks(y, years)
# Out:
# ([<matplotlib.axis.YTick at 0x1e4fed99660>,
#   <matplotlib.axis.YTick at 0x1e4fed99000>,
#   <matplotlib.axis.YTick at 0x1e4fed98550>],
#  [Text(0, 0, '2018'), Text(0, 1, '2019'), Text(0, 2, '2020')])

# %%
#산점도 그리기
np.random.seed(0)

n = 50
x = np.random.rand(n)
y = np.random.rand(n)

plt.scatter(x, y)

# %%
#산점도에 색상과 크기 지정하기
# scatter() 함수의 s, c 파라미터는 각각 마커의 크기와 색상을 지정
# 마커의 크기는 size**2 의 형태로 지정
np.random.seed(0)

n = 50
x = np.random.rand(n)
y = np.random.rand(n)
area = (30 * np.random.rand(n))**2
colors = np.random.rand(n)
#size와 color를 추가로 지정한다. 
plt.scatter(x, y, s=area, c=colors)

# %%
#투명도와 컬러맵을 지정한다. 
# alpha 파라미터는 마커의 투명도를 지정
# 0에서 1 사이의 값을 입력
# cmap 파라미터에 컬러맵에 해당하는 문자열을 지정
np.random.seed(0)

n = 50
x = np.random.rand(n)
y = np.random.rand(n)
area = (30 * np.random.rand(n))**2
colors = np.random.rand(n)

plt.scatter(x, y, s=area, c=colors, alpha=0.5, cmap='Spectral')
plt.colorbar()
plt.show()

# %%
#3차원 산점도 그리기 
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np

n = 100
xmin, xmax, ymin, ymax, zmin, zmax = 0, 20, 0, 20, 0, 50
cmin, cmax = 0, 2

# xs, ys는 0에서 20 사이, zs는 0에서 50 사이의 값을 갖도록 범위를 정해준다. 
# color는 0에서 2 사이의 값을 갖는 실수이고, 이 값을 통해 각각 다른 색을 표현
xs = np.array([(xmax - xmin) * np.random.random_sample() + xmin for i in range(n)])
ys = np.array([(ymax - ymin) * np.random.random_sample() + ymin for i in range(n)])
zs = np.array([(zmax - zmin) * np.random.random_sample() + zmin for i in range(n)])
color = np.array([(cmax - cmin) * np.random.random_sample() + cmin for i in range(n)])

fig = plt.figure(figsize=(6, 6))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(xs, ys, zs, c=color, marker='o', s=15, cmap='Greens')

# %%
#히스토그램
#히스토그램(Histogram)은 도수분포표를 그래프로 
#나타낸 것으로서, 가로축은 계급, 세로축은 도수 (횟수나 개수 등)를
#나타낸다. 
weight = [68, 81, 64, 56, 78, 74, 61, 77, 66, 68, 59, 71,
          80, 59, 67, 81, 69, 73, 69, 74, 70, 65]

plt.hist(weight)
# Out:
# (array([1., 2., 1., 2., 4., 3., 2., 2., 2., 3.]),
#  array([56. , 58.5, 61. , 63.5, 66. , 68.5, 71. , 73.5, 76. , 78.5, 81. ]),
#  <BarContainer object of 10 artists>)

# %%
# hist() 함수의 bins 파라미터는 히스토그램의 가로축 구간의 개수를 지정합니다.
# 아래 그림과 같이 구간의 개수에 따라 히스토그램 분포의 형태가 달라질 수 있기 때문에
# 적절한 구간의 개수를 지정해야 합니다.
weight = [68, 81, 64, 56, 78, 74, 61, 77, 66, 68, 59, 71,
          80, 59, 67, 81, 69, 73, 69, 74, 70, 65]

plt.hist(weight, label='bins=10')
plt.hist(weight, bins=30, label='bins=30')
plt.legend()

# %%
#누적 히스토그램
# cumulative 파라미터를 True로 지정하면 누적 히스토그램을 나타낸다.
weight = [68, 81, 64, 56, 78, 74, 61, 77, 66, 68, 59, 71,
          80, 59, 67, 81, 69, 73, 69, 74, 70, 65]

plt.hist(weight, cumulative=True, label='cumulative=True')
plt.hist(weight, cumulative=False, label='cumulative=False')
plt.legend(loc='upper left')

# %%
#히스토그램의 종류 지정하기 
weight = [68, 81, 64, 56, 78, 74, 61, 77, 66, 68, 59, 71,
        80, 59, 67, 81, 69, 73, 69, 74, 70, 65]
weight2 = [52, 67, 84, 66, 58, 78, 71, 57, 76, 62, 51, 79,
        69, 64, 76, 57, 63, 53, 79, 64, 50, 61]

plt.hist((weight, weight2), histtype='bar')
plt.title('histtype - bar')
plt.figure()

plt.hist((weight, weight2), histtype='barstacked')
plt.title('histtype - barstacked')
plt.figure()

plt.hist((weight, weight2), histtype='step')
plt.title('histtype - step')
plt.figure()

plt.hist((weight, weight2), histtype='stepfilled')
plt.title('histtype - stepfilled')
# Out:
# Text(0.5, 1.0, 'histtype - stepfilled')

# %%
# 파이 차트 (Pie chart, 원 그래프)는 범주별 구성 비율을 원형으로 표현
# 위의 그림과 같이 부채꼴의 중심각을 구성 비율에 비례하도록 표현
# 우선 각 영역의 비율과 이름을 ratio와 labels로 지정해주고,
# pie() 함수에 순서대로 입력
# autopct는 부채꼴 안에 표시될 숫자의 형식을 지정 
ratio = [34, 32, 16, 18]
labels = ['Apple', 'Banana', 'Melon', 'Grapes']

plt.pie(ratio, labels=labels, autopct='%.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x1e4fe9b9ed0>,
#   <matplotlib.patches.Wedge at 0x1e4fe9b97b0>,
#   <matplotlib.patches.Wedge at 0x1e4fe9ba230>,
#   <matplotlib.patches.Wedge at 0x1e4fe9ba770>],
#  [Text(0.5299289668959425, 0.9639373890687087, 'Apple'),
#   Text(-1.0999999999999959, -9.616505800409723e-08, 'Banana'),
#   Text(-0.0690695864845589, -1.097829400327233, 'Melon'),
#   Text(0.9287606853592857, -0.5894095259927091, 'Grapes')],
#  [Text(0.2890521637614232, 0.5257840304011138, '34.0%'),
#   Text(-0.5999999999999978, -5.2453668002234845e-08, '32.0%'),
#   Text(-0.03767431990066849, -0.5988160365421271, '16.0%'),
#   Text(0.5065967374687013, -0.3214961050869322, '18.0%')])

# %%
#시작각도와 방향을 설정하기
#startangle는 부채꼴이 그려지는 시작 각도를 설정
#디폴트는 0도 (양의 방향 x축)로 설정되어 있다. 
# counterclock=False로 설정하면 시계 방향 순서로 부채꼴 영역이 표시
ratio = [34, 32, 16, 18]
labels = ['Apple', 'Banana', 'Melon', 'Grapes']

plt.pie(ratio, labels=labels, autopct='%.1f%%', startangle=260, counterclock=False)
# Out:
# ([<matplotlib.patches.Wedge at 0x1e4fe966920>,
#   <matplotlib.patches.Wedge at 0x1e4fe965d20>,
#   <matplotlib.patches.Wedge at 0x1e4fe9665c0>,
#   <matplotlib.patches.Wedge at 0x1e4fe964070>],
#  [Text(-1.0413142392345422, -0.3544921087519252, 'Apple'),
#   Text(0.1910130394349517, 1.0832885205548066, 'Banana'),
#   Text(1.0931447047878378, -0.1226158814930238, 'Melon'),
#   Text(0.41917727552388656, -1.0170006940432106, 'Grapes')],
#  [Text(-0.567989585037023, -0.19335933204650463, '34.0%'),
#   Text(0.10418893060088273, 0.590884647575349, '32.0%'),
#   Text(0.5962607480660933, -0.06688138990528569, '16.0%'),
#   Text(0.22864215028575627, -0.5547276512962965, '18.0%')])

# %%
#중심에서 벗어나는 정도 지정하기
#explode는 부채꼴이 파이 차트의 중심에서 벗어나는 정도를 설정
#‘Banana’와 ‘Grapes’ 영역에 대해서 반지름의 10% 만큼 벗어나도록 
#설정
ratio = [34, 32, 16, 18]
labels = ['Apple', 'Banana', 'Melon', 'Grapes']
explode = [0, 0.10, 0, 0.10]

plt.pie(ratio, labels=labels, autopct='%.1f%%', 
        startangle=260, counterclock=False, explode=explode)
# Out:
# ([<matplotlib.patches.Wedge at 0x1e4fe9530a0>,
#   <matplotlib.patches.Wedge at 0x1e4fe952f20>,
#   <matplotlib.patches.Wedge at 0x1e4fe953d90>,
#   <matplotlib.patches.Wedge at 0x1e4fe953dc0>],
#  [Text(-1.0413142392345422, -0.3544921087519252, 'Apple'),
#   Text(0.2083778612017655, 1.1817692951506982, 'Banana'),
#   Text(1.0931447047878378, -0.1226158814930238, 'Melon'),
#   Text(0.4572843005715126, -1.1094553025925933, 'Grapes')],
#  [Text(-0.567989585037023, -0.19335933204650463, '34.0%'),
#   Text(0.12155375236769653, 0.6893654221712405, '32.0%'),
#   Text(0.5962607480660933, -0.06688138990528569, '16.0%'),
#   Text(0.2667491753333823, -0.6471822598456793, '18.0%')])

# %%
#그림자 나타내기
# shadow를 True로 설정하면, 파이 차트에 그림자가 표시
ratio = [34, 32, 16, 18]
labels = ['Apple', 'Banana', 'Melon', 'Grapes']
explode = [0.05, 0.05, 0.05, 0.05]

plt.pie(ratio, labels=labels, autopct='%.1f%%', 
        startangle=260, counterclock=False, 
        explode=explode, shadow=True)
# Out:
# ([<matplotlib.patches.Wedge at 0x1e4fe8c5570>,
#   <matplotlib.patches.Wedge at 0x1e4fe8c6830>,
#   <matplotlib.patches.Wedge at 0x1e4fe8c5300>,
#   <matplotlib.patches.Wedge at 0x1e4fe8c6320>],
#  [Text(-1.0886467046542943, -0.37060538642246726, 'Apple'),
#   Text(0.1996954503183586, 1.1325289078527523, 'Banana'),
#   Text(1.1428331004600123, -0.1281893306517976, 'Melon'),
#   Text(0.4382307880476996, -1.063227998317902, 'Grapes')],
#  [Text(-0.6153220504567749, -0.20947260971704668, '34.0%'),
#   Text(0.11287134148428962, 0.6401250348732948, '32.0%'),
#   Text(0.6459491437382677, -0.0724548390640595, '16.0%'),
#   Text(0.24769566280956928, -0.6009549555709879, '18.0%')])

# %%
#색상지정하기
ratio = [34, 32, 16, 18]
labels = ['Apple', 'Banana', 'Melon', 'Grapes']
explode = [0.05, 0.05, 0.05, 0.05]
colors = ['silver', 'gold', 'whitesmoke', 'lightgray']

plt.pie(ratio, labels=labels, autopct='%.1f%%', 
        startangle=260, counterclock=False, explode=explode, 
        shadow=True, colors=colors)
# Out:
# ([<matplotlib.patches.Wedge at 0x1e4fe8844c0>,
#   <matplotlib.patches.Wedge at 0x1e4fe886410>,
#   <matplotlib.patches.Wedge at 0x1e4fe83b730>,
#   <matplotlib.patches.Wedge at 0x1e4fe83ad40>],
#  [Text(-1.0886467046542943, -0.37060538642246726, 'Apple'),
#   Text(0.1996954503183586, 1.1325289078527523, 'Banana'),
#   Text(1.1428331004600123, -0.1281893306517976, 'Melon'),
#   Text(0.4382307880476996, -1.063227998317902, 'Grapes')],
#  [Text(-0.6153220504567749, -0.20947260971704668, '34.0%'),
#   Text(0.11287134148428962, 0.6401250348732948, '32.0%'),
#   Text(0.6459491437382677, -0.0724548390640595, '16.0%'),
#   Text(0.24769566280956928, -0.6009549555709879, '18.0%')])

# %%
# 히트맵 (Heatmap)은 다양한 값을 갖는 숫자 데이터를 열분포 형태와 같이 색상을 이용해서 시각화한 것
# 지도 이미지 위에 인구의 분포를 표현하거나, 웹사이트 이미지 위에 마우스의 클릭 위치를 표시하는 등의 다양한 정보를 시각화할 수 있다
# np.random.standard_normal() 로 만들어진 2차원 어레이 arr는 표준정규분포를 
#는 (30, 40) 형태의 2차원 어레이
# matshow() 함수에 어레이의 형태로 값들을 직접 입력하면 아래와 같은 그래프가 표시
arr = np.random.standard_normal((30, 40))

plt.matshow(arr)

# %%
#칼라바 표시
# 히트맵에 컬러바를 함께 나타내기 위해서 colorbar() 함수를 사용
arr = np.random.standard_normal((30, 40))

plt.matshow(arr)
plt.colorbar()

# %%
#색상 범위 지정하기 
# 히트맵에 표시될 색상의 범위를 지정하기 위해서 clim() 함수를 사용
# 아래 그림은 색상의 범위를 -1.0 ~ 1.0 으로 지정한 히트맵
# arr의 값 중 -1.0 보다 작거나 1.0 보다 큰 값에 대해서는 각각 -1.0, 1.0과 같은 색으로 나타냄

arr = np.random.standard_normal((30, 40))

plt.matshow(arr)
plt.colorbar(shrink=0.8, aspect=10)
# plt.clim(-1.0, 1.0)
plt.clim(-3.0, 3.0)

# %%
#컬러맵의 종류를 지정하기
# cmap 키워드 인자를 통해 표시할 컬러맵의 종류를 지정할 수 있다. 
# matplotlib.pyplot 모듈의 get_cmap() 함수를 이용해서 
#Matplotlib 컬러맵을 가져와서 matshow()에 입력해준다. 

arr = np.random.standard_normal((30, 40))
# cmap = plt.get_cmap('PiYG')
# cmap = plt.get_cmap('BuGn')
# cmap = plt.get_cmap('Greys')
cmap = plt.get_cmap('bwr')

plt.matshow(arr, cmap=cmap)
plt.colorbar()

# %%
#여러개의 그래프 그리기 
# matplotlib.pyplot 모듈의 subplot() 함수는 여러 개의 그래프를 
#하나의 그림에 나타내도록 한다. 

x1 = np.linspace(0.0, 5.0)
x2 = np.linspace(0.0, 2.0)

y1 = np.cos(2 * np.pi * x1) * np.exp(-x1)
y2 = np.cos(2 * np.pi * x2)

plt.subplot(2, 1, 1)                # nrows=2, ncols=1, index=1
plt.plot(x1, y1, 'o-')
plt.title('1st Graph')
plt.ylabel('Damped oscillation')

plt.subplot(2, 1, 2)                # nrows=2, ncols=1, index=2
plt.plot(x2, y2, '.-')
plt.title('2nd Graph')
plt.xlabel('time (s)')
plt.ylabel('Undamped')

plt.tight_layout()

# %%
x1 = np.linspace(0.0, 5.0)
x2 = np.linspace(0.0, 2.0)

y1 = np.cos(2 * np.pi * x1) * np.exp(-x1)
y2 = np.cos(2 * np.pi * x2)

plt.subplot(1, 2, 1)                # nrows=1, ncols=2, index=1
plt.plot(x1, y1, 'o-')
plt.title('1st Graph')
plt.xlabel('time (s)')
plt.ylabel('Damped oscillation')

plt.subplot(1, 2, 2)                # nrows=1, ncols=2, index=2
plt.plot(x2, y2, '.-')
plt.title('2nd Graph')
plt.xlabel('time (s)')
plt.ylabel('Undamped')

plt.tight_layout()

# %%
#객체 지향 인터페이스 사용하기
# 지금까지 matplotlib.pyplot 모듈의 다양한 함수들을 이용해서 간편하게 그래프를 그렸다. 
# Matplotlib는 그래프를 다루는 두 가지의 인터페이스를 제공하는데 
#첫번째는 MATLAB 스타일로 pyplot 모듈을 사용하는 방식이고, 두번째는 객체 지향 인터페이스이다.
fig, ax = plt.subplots()

# %%
# fig, ax = plt.subplots()과 같이 사용하지 않고 이 예제와 같이 사용할 수도 있다. 
# plt.figure()는 Figure 클래스의 인스턴스를 반환한다. 
# Figure 클래스의 인스턴스 fig의 메서드 add_axes()는 fig에 axes를 하나 추가한다. 
# add_axes([left, bottom, width, height])의 형태로 0에서 1 사이의 값을 입력한다. 

fig = plt.figure()
ax = fig.add_axes([0, 0, 1, 1])

# %%
#행과 열 설정하기 
# plt.subplots(nrows, ncols)의 형태로 행과 열의 개수를 지정
# 만약 지정하지 않으면 기본적으로 행과 열의 개수는 모두 1
fig, ax = plt.subplots(2, 2)

# %%
#그래프 그리기
x = np.arange(1, 5)     # [1, 2, 3, 4]

fig, ax = plt.subplots(2, 2, sharex=True, sharey=True, squeeze=True)
ax[0][0].plot(x, np.sqrt(x))      # left-top
ax[0][1].plot(x, x)               # right-top
ax[1][0].plot(x, -x+5)            # left-bottom
ax[1][1].plot(x, np.sqrt(-x+5))   # right-bottom

# %%
#스타일 지정하기
x = np.arange(1, 5)     # [1, 2, 3, 4]

fig, ax = plt.subplots(2, 2, sharex=True, sharey=True, squeeze=True)
ax[0][0].plot(x, np.sqrt(x), 'gray', linewidth=3)
ax[0][1].plot(x, x, 'g^-', markersize=10)
ax[1][0].plot(x, -x+5, 'ro--')
ax[1][1].plot(x, np.sqrt(-x+5), 'b.-.')

# %%
#제목과 범례 표시하기
# set_title()과 legend()를 이용해서 각각의 그래프에 제목과 범례를 설정할 수 있다. 
# set_title()은 입력한 문자열을 그래프의 제목으로 나타낸다.
# legend()는 plot()에서 label을 이용해서 지정한 문자열을 범례에 나타낸다. 

x = np.arange(1, 5)     # [1, 2, 3, 4]

fig, ax = plt.subplots(2, 2, sharex=True, sharey=True, squeeze=True)
ax[0][0].plot(x, np.sqrt(x), 'gray', linewidth=3, label='y=np.sqrt(x)')
ax[0][0].set_title('Graph 1')
ax[0][0].legend()
ax[0][1].plot(x, x, 'g^-', markersize=10, label='y=x')
ax[0][1].set_title('Graph 2')
ax[0][1].legend(loc='upper left')
ax[1][0].plot(x, -x+5, 'ro--', label='y=-x+5')
ax[1][0].set_title('Graph 3')
ax[1][0].legend(loc='lower left')
ax[1][1].plot(x, np.sqrt(-x+5), 'b.-.', label='y=np.sqrt(-x+5)')
ax[1][1].set_title('Graph 4')
ax[1][1].legend(loc='upper center')

# %%
#축 위치 조절하기
plt.style.use('default')
plt.rcParams['figure.figsize'] = (6, 3)
plt.rcParams['font.size'] = 12


fig, ax = plt.subplots()

ax.set_title('Mean Squared Error', pad=20)
ax.set_xlim(-3, 3)
ax.set_ylim(0, 3)
ax.set_xticks([-3, -2, -1, 0, 1, 2, 3])
ax.set_yticks([1, 2, 3])

ax.spines['left'].set_position('center')        # 왼쪽 축을 가운데 위치로 이동
ax.spines['right'].set_visible(False)          # 오른쪽 축을 보이지 않도록
ax.spines['top'].set_visible(False)            # 위 축을 보이지 않도록
ax.spines['bottom'].set_position(('data', 0))   # 아래 축을 데이터 0의 위치로 이동
ax.tick_params('both', length=0)                # Tick의 눈금 길이 0

x = np.linspace(-3, 3, 100)
ax.set_xlabel('y_true - y_pred', fontdict={'fontsize': 14}, labelpad=10)
ax.plot(x, x**2, color='#4799FF', linewidth=5)

# %%
#두 종류의 그래프 그리기
# 1. 기본 스타일 설정
plt.style.use('default')
plt.rcParams['figure.figsize'] = (4, 3)
plt.rcParams['font.size'] = 12

# 2. 데이터 준비
x = np.arange(2020, 2027)
y1 = np.array([1, 3, 7, 5, 9, 7, 14])
y2 = np.array([1, 3, 5, 7, 9, 11, 13])

# 3. 그래프 그리기
fig, ax1 = plt.subplots()

ax1.plot(x, y1, '-s', color='green', markersize=7, linewidth=5, alpha=0.7, label='Price')
ax1.set_ylim(0, 18)
ax1.set_xlabel('Year')
ax1.set_ylabel('Price ($)')
ax1.tick_params(axis='both', direction='in')

ax2 = ax1.twinx()
ax2.bar(x, y2, color='deeppink', label='Demand', alpha=0.7, width=0.7)
ax2.set_ylim(0, 18)
ax2.set_ylabel(r'Demand ($\times10^6$)')
ax2.tick_params(axis='y', direction='in')
